# %% [markdown]
# # Multiview Training
# This code will produce a model that can take two views of the cow and hopfully achieve a better predication.

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras import layers
import keras
import tensorflow as tf
import numpy as np
import os
from PIL import Image
from tqdm.notebook import tqdm
import keract
from matplotlib import pyplot as plt
import cv2
from generator import Generator
from importlib import reload

# %%
# fix some memory expansion issues by allowing growth on the gpu
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
DATABASE_LOCATION = 'E:/cattle_data'
INPUT_PATH = DATABASE_LOCATION+'/training'
DATASET = 'two_view_training.json'

# %% [markdown]
# ## Load Data

# %%
# load training data
import pandas as pd
df = pd.read_json(os.path.join(INPUT_PATH, DATASET))
print(len(df))
df.head()
# Out:
# 27901
#         date  weight  side_id  end_id  \
# 0 2021-11-30     565   126454  126452
# 1 2021-11-30     565   126463  126446
# 2 2021-11-30     565   126453  126451
# 3 2021-11-30     565   126460  126461
# 4 2021-11-30     565   126449  126447
#
#                                            side_path  \
# 0  E:/cattle_data/training/two_views/1_0_126454_s...
# 1  E:/cattle_data/training/two_views/1_1_126463_s...
# 2  E:/cattle_data/training/two_views/1_2_126453_s...
# 3  E:/cattle_data/training/two_views/1_3_126460_s...
# 4  E:/cattle_data/training/two_views/1_4_126449_s...
#
#                                             end_path
# 0  E:/cattle_data/training/two_views/1_0_126452_e...
# 1  E:/cattle_data/training/two_views/1_1_126446_e...
# 2  E:/cattle_data/training/two_views/1_2_126451_e...
# 3  E:/cattle_data/training/two_views/1_3_126461_e...
# 4  E:/cattle_data/training/two_views/1_4_126447_e...

# %% [markdown]
# ### Prep Data

# %%
# trim the data to a constrained weight range 
df_trim = df[(df.weight > 400) & (df.weight < 1450)]

# %%
# reserve recent data for evaluation
# last reserve from 2022-01-22
cuttoff = '2022-02-13'
eval_df = df_trim[df_trim.date > cuttoff].copy()
training_df = df_trim[df_trim.date < cuttoff].copy()

# %%
len(eval_df)
# Out:
# 6202

# %%
# split the training data into training and testing
def train_test_split(d, frac=0.2):
    test = d.sample(frac=frac, axis=0)
    train = d.drop(index=test.index).sample(frac=1, axis=0)
    return train, test

# %%
train_df, test_df = train_test_split(training_df)

# %%
Generator = reload(generator).Generator

# %%
train_gen = Generator(train_df, X_col=['side_path', 'end_path'], y_col='weight', batch_size=64, model_input_shape=(224,224), color='rgb', shuffle=True)
val_gen = Generator(test_df, X_col=['side_path', 'end_path'], y_col='weight', batch_size=64, model_input_shape=(224,224), color='rgb', shuffle=True)

# %% [markdown]
# ## Create Two View Model

# %%
# load the model pretrained on single images
side_model = keras.models.load_model(DATABASE_LOCATION+"/models/exceptionet_best_model")
end_model = keras.models.load_model(DATABASE_LOCATION+"/models/exceptionet_best_model")

# %%
side_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_average_pooling2d_1   (None, 2048)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 100)               204900
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 21,066,481
# Trainable params: 20,983,441
# Non-trainable params: 83,040
# _________________________________________________________________

# %%
# unfreeze layers
for layer in side_model.layers:
    layer.trainable = True
for layer in end_model.layers:
    layer.trainable = True

# %%
# take off last layer
side_out = side_model.layers[-2].output
end_out = end_model.layers[-2].output

side_model = tf.keras.Model(inputs = side_model.input, outputs = side_out)
end_model = tf.keras.Model(inputs = end_model.input, outputs = end_out)

# %%
# create new inputs for side and end
side_input_layer = tf.keras.Input(shape=(224, 224, 3))
end_input_layer = tf.keras.Input(shape=(224, 224, 3))

side = side_model(side_input_layer, training=True)
end = end_model(end_input_layer, training=True)

# combine side and end features 
x = tf.keras.layers.concatenate([side, end])
#x = tf.keras.layers.Activation('relu')(x)

bias_init = tf.keras.initializers.Constant(700.0)#df.weight.mean())
outputs = tf.keras.layers.Dense(1, bias_initializer=bias_init)(x) # reduce to one node for weight prediction

model_xcept = tf.keras.Model(inputs = [side_input_layer, end_input_layer], outputs = outputs)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model_xcept.compile(
    loss= "mean_squared_error" , 
    optimizer=opt, 
    metrics=["mean_squared_error"])

# %%
model_xcept.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  input_6 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  model_6 (Functional)           (None, 100)          21066380    ['input_5[0][0]']
#
#  model_7 (Functional)           (None, 100)          21066380    ['input_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 200)          0           ['model_6[0][0]',
#                                                                   'model_7[0][0]']
#
#  dense_2 (Dense)                (None, 1)            201         ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 42,132,961
# Trainable params: 42,023,905
# Non-trainable params: 109,056
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the Model

# %%
hist = model_xcept.fit(
        train_gen,
        steps_per_epoch=50,
        epochs=100,
        validation_data=val_gen,
        validation_steps=15,
        #callbacks=[tensorboard_callback]
        verbose=1,
        )
# Out:
# Epoch 1/100
# 50/50 [==============================] - 146s 3s/step - loss: 54830.4102 - mean_squared_error: 54830.4102 - val_loss: 39055.6094 - val_mean_squared_error: 39055.6094
# Epoch 2/100
# 50/50 [==============================] - 117s 2s/step - loss: 41942.5508 - mean_squared_error: 41942.5508 - val_loss: 36398.0820 - val_mean_squared_error: 36398.0820
# Epoch 3/100
# 50/50 [==============================] - 112s 2s/step - loss: 35636.5820 - mean_squared_error: 35636.5820 - val_loss: 34218.2734 - val_mean_squared_error: 34218.2734
# Epoch 4/100
# 50/50 [==============================] - 108s 2s/step - loss: 33348.8906 - mean_squared_error: 33348.8906 - val_loss: 43775.4766 - val_mean_squared_error: 43775.4766
# Epoch 5/100
# 50/50 [==============================] - 105s 2s/step - loss: 34175.7891 - mean_squared_error: 34175.7891 - val_loss: 36566.9805 - val_mean_squared_error: 36566.9805
# Epoch 6/100
# 50/50 [==============================] - 107s 2s/step - loss: 31874.5625 - mean_squared_error: 31874.5625 - val_loss: 35940.6406 - val_mean_squared_error: 35940.6406
# Epoch 7/100
# 50/50 [==============================] - 317s 6s/step - loss: 29269.6309 - mean_squared_error: 29269.6309 - val_loss: 35892.8867 - val_mean_squared_error: 35892.8867
# Epoch 8/100
# 50/50 [==============================] - 104s 2s/step - loss: 25656.4258 - mean_squared_error: 25656.4258 - val_loss: 30816.4102 - val_mean_squared_error: 30816.4102
# Epoch 9/100
# 50/50 [==============================] - 97s 2s/step - loss: 24783.4648 - mean_squared_error: 24783.4648 - val_loss: 33188.0742 - val_mean_squared_error: 33188.0742
# Epoch 10/100
# 50/50 [==============================] - 99s 2s/step - loss: 22812.0625 - mean_squared_error: 22812.0625 - val_loss: 25734.3672 - val_mean_squared_error: 25734.3672
# Epoch 11/100
# 50/50 [==============================] - 96s 2s/step - loss: 20649.7441 - mean_squared_error: 20649.7441 - val_loss: 25054.6172 - val_mean_squared_error: 25054.6172
# Epoch 12/100
# 50/50 [==============================] - 96s 2s/step - loss: 17916.2344 - mean_squared_error: 17916.2344 - val_loss: 24627.1758 - val_mean_squared_error: 24627.1758
# Epoch 13/100
# 50/50 [==============================] - 97s 2s/step - loss: 16749.0957 - mean_squared_error: 16749.0957 - val_loss: 23338.0371 - val_mean_squared_error: 23338.0371
# Epoch 14/100
# 50/50 [==============================] - 98s 2s/step - loss: 15766.5859 - mean_squared_error: 15766.5859 - val_loss: 23964.8066 - val_mean_squared_error: 23964.8066
# Epoch 15/100
# 50/50 [==============================] - 95s 2s/step - loss: 14312.7354 - mean_squared_error: 14312.7354 - val_loss: 20651.0645 - val_mean_squared_error: 20651.0645
# Epoch 16/100
# 50/50 [==============================] - 95s 2s/step - loss: 12833.1289 - mean_squared_error: 12833.1289 - val_loss: 19558.7988 - val_mean_squared_error: 19558.7988
# Epoch 17/100
# 50/50 [==============================] - 95s 2s/step - loss: 12933.0439 - mean_squared_error: 12933.0439 - val_loss: 18188.8438 - val_mean_squared_error: 18188.8438
# Epoch 18/100
# 50/50 [==============================] - 96s 2s/step - loss: 12159.7822 - mean_squared_error: 12159.7822 - val_loss: 18356.7598 - val_mean_squared_error: 18356.7598
# Epoch 19/100
# 50/50 [==============================] - 94s 2s/step - loss: 10469.6680 - mean_squared_error: 10469.6680 - val_loss: 19157.3691 - val_mean_squared_error: 19157.3691
# Epoch 20/100
# 50/50 [==============================] - 100s 2s/step - loss: 10006.5664 - mean_squared_error: 10006.5664 - val_loss: 16928.6211 - val_mean_squared_error: 16928.6211
# Epoch 21/100
# 50/50 [==============================] - 94s 2s/step - loss: 9081.5947 - mean_squared_error: 9081.5947 - val_loss: 17674.8379 - val_mean_squared_error: 17674.8379
# Epoch 22/100
# 50/50 [==============================] - 95s 2s/step - loss: 8414.1367 - mean_squared_error: 8414.1367 - val_loss: 16537.1348 - val_mean_squared_error: 16537.1348
# Epoch 23/100
# 50/50 [==============================] - 95s 2s/step - loss: 7968.4224 - mean_squared_error: 7968.4224 - val_loss: 15672.9844 - val_mean_squared_error: 15672.9844
# Epoch 24/100
# 50/50 [==============================] - 95s 2s/step - loss: 8155.2964 - mean_squared_error: 8155.2964 - val_loss: 15953.6729 - val_mean_squared_error: 15953.6729
# Epoch 25/100
# 50/50 [==============================] - 94s 2s/step - loss: 7059.5762 - mean_squared_error: 7059.5762 - val_loss: 15970.0654 - val_mean_squared_error: 15970.0654
# Epoch 26/100
# 50/50 [==============================] - 95s 2s/step - loss: 7028.2632 - mean_squared_error: 7028.2632 - val_loss: 15154.0898 - val_mean_squared_error: 15154.0898
# Epoch 27/100
# 50/50 [==============================] - 95s 2s/step - loss: 7550.3755 - mean_squared_error: 7550.3755 - val_loss: 17358.2402 - val_mean_squared_error: 17358.2402
# Epoch 28/100
# 50/50 [==============================] - 95s 2s/step - loss: 6702.9287 - mean_squared_error: 6702.9287 - val_loss: 13414.2334 - val_mean_squared_error: 13414.2334
# Epoch 29/100
# 50/50 [==============================] - 95s 2s/step - loss: 6275.2881 - mean_squared_error: 6275.2881 - val_loss: 17122.4023 - val_mean_squared_error: 17122.4023
# Epoch 30/100
# 50/50 [==============================] - 95s 2s/step - loss: 5587.7988 - mean_squared_error: 5587.7988 - val_loss: 14446.6348 - val_mean_squared_error: 14446.6348
# Epoch 31/100
# 50/50 [==============================] - 95s 2s/step - loss: 5616.3252 - mean_squared_error: 5616.3252 - val_loss: 14693.0664 - val_mean_squared_error: 14693.0664
# Epoch 32/100
# 50/50 [==============================] - 95s 2s/step - loss: 5298.1948 - mean_squared_error: 5298.1948 - val_loss: 14263.6865 - val_mean_squared_error: 14263.6865
# Epoch 33/100
# 50/50 [==============================] - 94s 2s/step - loss: 5005.1714 - mean_squared_error: 5005.1714 - val_loss: 15073.4551 - val_mean_squared_error: 15073.4551
# Epoch 34/100
# 50/50 [==============================] - 97s 2s/step - loss: 5323.3198 - mean_squared_error: 5323.3198 - val_loss: 15126.1035 - val_mean_squared_error: 15126.1035
# Epoch 35/100
# 50/50 [==============================] - 94s 2s/step - loss: 5025.9707 - mean_squared_error: 5025.9707 - val_loss: 14916.7979 - val_mean_squared_error: 14916.7979
# Epoch 36/100
# 50/50 [==============================] - 94s 2s/step - loss: 4592.9673 - mean_squared_error: 4592.9673 - val_loss: 13710.6738 - val_mean_squared_error: 13710.6738
# Epoch 37/100
# 50/50 [==============================] - 95s 2s/step - loss: 4460.6445 - mean_squared_error: 4460.6445 - val_loss: 14913.6768 - val_mean_squared_error: 14913.6768
# Epoch 38/100
# 50/50 [==============================] - 96s 2s/step - loss: 4306.4800 - mean_squared_error: 4306.4800 - val_loss: 14537.6982 - val_mean_squared_error: 14537.6982
# Epoch 39/100
# 50/50 [==============================] - 94s 2s/step - loss: 3822.8508 - mean_squared_error: 3822.8508 - val_loss: 15056.6533 - val_mean_squared_error: 15056.6533
# Epoch 40/100
# 50/50 [==============================] - 95s 2s/step - loss: 6085.0513 - mean_squared_error: 6085.0513 - val_loss: 14085.5146 - val_mean_squared_error: 14085.5146
# Epoch 41/100
# 50/50 [==============================] - 95s 2s/step - loss: 6542.2715 - mean_squared_error: 6542.2715 - val_loss: 14979.8438 - val_mean_squared_error: 14979.8438
# Epoch 42/100
# 50/50 [==============================] - 95s 2s/step - loss: 6280.7910 - mean_squared_error: 6280.7910 - val_loss: 14655.9688 - val_mean_squared_error: 14655.9688
# Epoch 43/100
# 50/50 [==============================] - 97s 2s/step - loss: 6205.0093 - mean_squared_error: 6205.0093 - val_loss: 14336.8184 - val_mean_squared_error: 14336.8184
# Epoch 44/100
# 50/50 [==============================] - 94s 2s/step - loss: 5291.2563 - mean_squared_error: 5291.2563 - val_loss: 14067.8008 - val_mean_squared_error: 14067.8008
# Epoch 45/100
# 50/50 [==============================] - 94s 2s/step - loss: 14909.4492 - mean_squared_error: 14909.4492 - val_loss: 26160.6660 - val_mean_squared_error: 26160.6660
# Epoch 46/100
# 50/50 [==============================] - 95s 2s/step - loss: 13185.1387 - mean_squared_error: 13185.1387 - val_loss: 19581.6211 - val_mean_squared_error: 19581.6211
# Epoch 47/100
# 50/50 [==============================] - 94s 2s/step - loss: 9444.4766 - mean_squared_error: 9444.4766 - val_loss: 15909.9023 - val_mean_squared_error: 15909.9023
# Epoch 48/100
# 50/50 [==============================] - 96s 2s/step - loss: 8026.4033 - mean_squared_error: 8026.4033 - val_loss: 14825.3418 - val_mean_squared_error: 14825.3418
# Epoch 49/100
# 50/50 [==============================] - 94s 2s/step - loss: 5779.4004 - mean_squared_error: 5779.4004 - val_loss: 14022.6719 - val_mean_squared_error: 14022.6719
# Epoch 50/100
# 50/50 [==============================] - 97s 2s/step - loss: 5673.9756 - mean_squared_error: 5673.9756 - val_loss: 16700.1953 - val_mean_squared_error: 16700.1953
# Epoch 51/100
# 50/50 [==============================] - 95s 2s/step - loss: 5166.0220 - mean_squared_error: 5166.0220 - val_loss: 16208.8936 - val_mean_squared_error: 16208.8936
# Epoch 52/100
# 50/50 [==============================] - 100s 2s/step - loss: 4428.8379 - mean_squared_error: 4428.8379 - val_loss: 13550.0020 - val_mean_squared_error: 13550.0020
# Epoch 53/100
# 50/50 [==============================] - 94s 2s/step - loss: 4351.1831 - mean_squared_error: 4351.1831 - val_loss: 15784.9502 - val_mean_squared_error: 15784.9502
# Epoch 54/100
# 50/50 [==============================] - 98s 2s/step - loss: 3880.8352 - mean_squared_error: 3880.8352 - val_loss: 14961.5098 - val_mean_squared_error: 14961.5098
# Epoch 55/100
# 50/50 [==============================] - 94s 2s/step - loss: 3570.5913 - mean_squared_error: 3570.5913 - val_loss: 12738.9961 - val_mean_squared_error: 12738.9961
# Epoch 56/100
# 50/50 [==============================] - 95s 2s/step - loss: 3513.2576 - mean_squared_error: 3513.2576 - val_loss: 13679.5586 - val_mean_squared_error: 13679.5586
# Epoch 57/100
# 50/50 [==============================] - 94s 2s/step - loss: 3153.7307 - mean_squared_error: 3153.7307 - val_loss: 14092.2139 - val_mean_squared_error: 14092.2139
# Epoch 58/100
# 50/50 [==============================] - 95s 2s/step - loss: 2825.0215 - mean_squared_error: 2825.0215 - val_loss: 13804.2988 - val_mean_squared_error: 13804.2988
# Epoch 59/100
# 50/50 [==============================] - 94s 2s/step - loss: 2867.6052 - mean_squared_error: 2867.6052 - val_loss: 13202.0723 - val_mean_squared_error: 13202.0723
# Epoch 60/100
# 50/50 [==============================] - 94s 2s/step - loss: 3037.6897 - mean_squared_error: 3037.6897 - val_loss: 14175.1504 - val_mean_squared_error: 14175.1504
# Epoch 61/100
# 50/50 [==============================] - 94s 2s/step - loss: 2963.4346 - mean_squared_error: 2963.4346 - val_loss: 11699.5127 - val_mean_squared_error: 11699.5127
# Epoch 62/100
# 50/50 [==============================] - 96s 2s/step - loss: 2875.3831 - mean_squared_error: 2875.3831 - val_loss: 13604.9316 - val_mean_squared_error: 13604.9316
# Epoch 63/100
# 50/50 [==============================] - 97s 2s/step - loss: 2418.3955 - mean_squared_error: 2418.3955 - val_loss: 12926.2764 - val_mean_squared_error: 12926.2764
# Epoch 64/100
# 50/50 [==============================] - 101s 2s/step - loss: 2521.2668 - mean_squared_error: 2521.2668 - val_loss: 14326.9004 - val_mean_squared_error: 14326.9004
# Epoch 65/100
# 50/50 [==============================] - 99s 2s/step - loss: 2329.0786 - mean_squared_error: 2329.0786 - val_loss: 12858.8213 - val_mean_squared_error: 12858.8213
# Epoch 66/100
# 50/50 [==============================] - 103s 2s/step - loss: 2078.6213 - mean_squared_error: 2078.6213 - val_loss: 12983.5420 - val_mean_squared_error: 12983.5420
# Epoch 67/100
# 50/50 [==============================] - 102s 2s/step - loss: 3724.7988 - mean_squared_error: 3724.7988 - val_loss: 15038.5947 - val_mean_squared_error: 15038.5947
# Epoch 68/100
# 50/50 [==============================] - 99s 2s/step - loss: 2926.9304 - mean_squared_error: 2926.9304 - val_loss: 13683.3730 - val_mean_squared_error: 13683.3730
# Epoch 69/100
# 50/50 [==============================] - 99s 2s/step - loss: 2744.4866 - mean_squared_error: 2744.4866 - val_loss: 12955.9697 - val_mean_squared_error: 12955.9697
# Epoch 70/100
# 50/50 [==============================] - 99s 2s/step - loss: 2785.8406 - mean_squared_error: 2785.8406 - val_loss: 12078.4912 - val_mean_squared_error: 12078.4912
# Epoch 71/100
# 50/50 [==============================] - 101s 2s/step - loss: 2439.0491 - mean_squared_error: 2439.0491 - val_loss: 11786.2725 - val_mean_squared_error: 11786.2725
# Epoch 72/100
# 50/50 [==============================] - 105s 2s/step - loss: 2143.7893 - mean_squared_error: 2143.7893 - val_loss: 13517.1865 - val_mean_squared_error: 13517.1865
# Epoch 73/100
# 50/50 [==============================] - 100s 2s/step - loss: 2085.4663 - mean_squared_error: 2085.4663 - val_loss: 12193.3730 - val_mean_squared_error: 12193.3730
# Epoch 74/100
# 50/50 [==============================] - 102s 2s/step - loss: 2065.3267 - mean_squared_error: 2065.3267 - val_loss: 12872.0020 - val_mean_squared_error: 12872.0020
# Epoch 75/100
# 50/50 [==============================] - 99s 2s/step - loss: 1954.8740 - mean_squared_error: 1954.8740 - val_loss: 13008.1719 - val_mean_squared_error: 13008.1719
# Epoch 76/100
# 50/50 [==============================] - 104s 2s/step - loss: 1899.5844 - mean_squared_error: 1899.5844 - val_loss: 11655.6777 - val_mean_squared_error: 11655.6777
# Epoch 77/100
# 50/50 [==============================] - 100s 2s/step - loss: 2194.6543 - mean_squared_error: 2194.6543 - val_loss: 13175.4375 - val_mean_squared_error: 13175.4375
# Epoch 78/100
# 50/50 [==============================] - 102s 2s/step - loss: 1990.7087 - mean_squared_error: 1990.7087 - val_loss: 11383.4854 - val_mean_squared_error: 11383.4854
# Epoch 79/100
# 50/50 [==============================] - 99s 2s/step - loss: 1867.0294 - mean_squared_error: 1867.0294 - val_loss: 13040.5459 - val_mean_squared_error: 13040.5459
# Epoch 80/100
# 50/50 [==============================] - 100s 2s/step - loss: 1795.1980 - mean_squared_error: 1795.1980 - val_loss: 13067.3936 - val_mean_squared_error: 13067.3936
# Epoch 81/100
# 50/50 [==============================] - 104s 2s/step - loss: 1799.4062 - mean_squared_error: 1799.4062 - val_loss: 11763.7539 - val_mean_squared_error: 11763.7539
# Epoch 82/100
# 50/50 [==============================] - 99s 2s/step - loss: 1722.1250 - mean_squared_error: 1722.1250 - val_loss: 13066.6865 - val_mean_squared_error: 13066.6865
# Epoch 83/100
# 50/50 [==============================] - 101s 2s/step - loss: 1724.1412 - mean_squared_error: 1724.1412 - val_loss: 13302.3623 - val_mean_squared_error: 13302.3623
# Epoch 84/100
# 50/50 [==============================] - 99s 2s/step - loss: 1775.2382 - mean_squared_error: 1775.2382 - val_loss: 12156.9209 - val_mean_squared_error: 12156.9209
# Epoch 85/100
# 50/50 [==============================] - 100s 2s/step - loss: 1684.7831 - mean_squared_error: 1684.7831 - val_loss: 10715.4316 - val_mean_squared_error: 10715.4316
# Epoch 86/100
# 50/50 [==============================] - 102s 2s/step - loss: 1689.0100 - mean_squared_error: 1689.0100 - val_loss: 12305.7568 - val_mean_squared_error: 12305.7568
# Epoch 87/100
# 50/50 [==============================] - 99s 2s/step - loss: 1590.0135 - mean_squared_error: 1590.0135 - val_loss: 12976.5723 - val_mean_squared_error: 12976.5723
# Epoch 88/100
# 50/50 [==============================] - 100s 2s/step - loss: 1462.1226 - mean_squared_error: 1462.1226 - val_loss: 12303.7432 - val_mean_squared_error: 12303.7432
# Epoch 89/100
# 50/50 [==============================] - 100s 2s/step - loss: 1470.0125 - mean_squared_error: 1470.0125 - val_loss: 12066.2793 - val_mean_squared_error: 12066.2793
# Epoch 90/100
# 50/50 [==============================] - 102s 2s/step - loss: 1439.5847 - mean_squared_error: 1439.5847 - val_loss: 11953.7148 - val_mean_squared_error: 11953.7148
# Epoch 91/100
# 50/50 [==============================] - 100s 2s/step - loss: 1459.7288 - mean_squared_error: 1459.7288 - val_loss: 12788.2754 - val_mean_squared_error: 12788.2754
# Epoch 92/100
# 50/50 [==============================] - 101s 2s/step - loss: 1560.4052 - mean_squared_error: 1560.4052 - val_loss: 11258.9805 - val_mean_squared_error: 11258.9805
# Epoch 93/100
# 50/50 [==============================] - 100s 2s/step - loss: 1496.9888 - mean_squared_error: 1496.9888 - val_loss: 11604.8379 - val_mean_squared_error: 11604.8379
# Epoch 94/100
# 50/50 [==============================] - 104s 2s/step - loss: 1511.7155 - mean_squared_error: 1511.7155 - val_loss: 12511.7920 - val_mean_squared_error: 12511.7920
# Epoch 95/100
# 50/50 [==============================] - 102s 2s/step - loss: 1460.0796 - mean_squared_error: 1460.0796 - val_loss: 12421.7998 - val_mean_squared_error: 12421.7998
# Epoch 96/100
# 50/50 [==============================] - 100s 2s/step - loss: 1442.8434 - mean_squared_error: 1442.8434 - val_loss: 13167.2363 - val_mean_squared_error: 13167.2363
# Epoch 97/100
# 50/50 [==============================] - 101s 2s/step - loss: 1442.8441 - mean_squared_error: 1442.8441 - val_loss: 12820.5098 - val_mean_squared_error: 12820.5098
# Epoch 98/100
# 50/50 [==============================] - 100s 2s/step - loss: 1360.2089 - mean_squared_error: 1360.2089 - val_loss: 13724.4385 - val_mean_squared_error: 13724.4385
# Epoch 99/100
# 50/50 [==============================] - 101s 2s/step - loss: 1529.4176 - mean_squared_error: 1529.4176 - val_loss: 12371.7051 - val_mean_squared_error: 12371.7051
# Epoch 100/100
# 50/50 [==============================] - 106s 2s/step - loss: 1432.5942 - mean_squared_error: 1432.5942 - val_loss: 12243.7959 - val_mean_squared_error: 12243.7959

# %%
history = hist
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
hist = model_xcept.fit(
        train_gen,
        steps_per_epoch=50,
        epochs=20,
        validation_data=val_gen,
        validation_steps=15,
        #callbacks=[tensorboard_callback]
        verbose=1,
        )
# Out:
# Epoch 1/20
# 50/50 [==============================] - 111s 2s/step - loss: 3215.0122 - mean_squared_error: 3215.0122 - val_loss: 12320.8730 - val_mean_squared_error: 12320.8730
# Epoch 2/20
# 50/50 [==============================] - 99s 2s/step - loss: 2533.2051 - mean_squared_error: 2533.2051 - val_loss: 12634.8467 - val_mean_squared_error: 12634.8467
# Epoch 3/20
# 50/50 [==============================] - 100s 2s/step - loss: 1904.0093 - mean_squared_error: 1904.0093 - val_loss: 12607.6973 - val_mean_squared_error: 12607.6973
# Epoch 4/20
# 50/50 [==============================] - 99s 2s/step - loss: 1887.0127 - mean_squared_error: 1887.0127 - val_loss: 11626.3213 - val_mean_squared_error: 11626.3213
# Epoch 5/20
# 50/50 [==============================] - 100s 2s/step - loss: 1723.8599 - mean_squared_error: 1723.8599 - val_loss: 11451.2246 - val_mean_squared_error: 11451.2246
# Epoch 6/20
# 50/50 [==============================] - 99s 2s/step - loss: 1543.2599 - mean_squared_error: 1543.2599 - val_loss: 11023.5713 - val_mean_squared_error: 11023.5713
# Epoch 7/20
# 50/50 [==============================] - 99s 2s/step - loss: 1432.3315 - mean_squared_error: 1432.3315 - val_loss: 11608.6709 - val_mean_squared_error: 11608.6709
# Epoch 8/20
# 50/50 [==============================] - 100s 2s/step - loss: 1316.9576 - mean_squared_error: 1316.9576 - val_loss: 11722.9980 - val_mean_squared_error: 11722.9980
# Epoch 9/20
# 50/50 [==============================] - 98s 2s/step - loss: 1257.8484 - mean_squared_error: 1257.8484 - val_loss: 12744.6494 - val_mean_squared_error: 12744.6494
# Epoch 10/20
# 50/50 [==============================] - 99s 2s/step - loss: 1239.8890 - mean_squared_error: 1239.8890 - val_loss: 11781.4043 - val_mean_squared_error: 11781.4043
# Epoch 11/20
# 50/50 [==============================] - 99s 2s/step - loss: 1139.7302 - mean_squared_error: 1139.7302 - val_loss: 12558.1934 - val_mean_squared_error: 12558.1934
# Epoch 12/20
# 50/50 [==============================] - 99s 2s/step - loss: 1226.8469 - mean_squared_error: 1226.8469 - val_loss: 12887.0908 - val_mean_squared_error: 12887.0908
# Epoch 13/20
# 50/50 [==============================] - 99s 2s/step - loss: 1196.4482 - mean_squared_error: 1196.4482 - val_loss: 11887.5400 - val_mean_squared_error: 11887.5400
# Epoch 14/20
# 50/50 [==============================] - 100s 2s/step - loss: 1061.8585 - mean_squared_error: 1061.8585 - val_loss: 11953.0645 - val_mean_squared_error: 11953.0645
# Epoch 15/20
# 50/50 [==============================] - 100s 2s/step - loss: 1050.9403 - mean_squared_error: 1050.9403 - val_loss: 11708.6777 - val_mean_squared_error: 11708.6777
# Epoch 16/20
# 50/50 [==============================] - 101s 2s/step - loss: 1017.9981 - mean_squared_error: 1017.9981 - val_loss: 12326.5020 - val_mean_squared_error: 12326.5020
# Epoch 17/20
# 50/50 [==============================] - 99s 2s/step - loss: 972.8710 - mean_squared_error: 972.8710 - val_loss: 12745.4746 - val_mean_squared_error: 12745.4746
# Epoch 18/20
# 50/50 [==============================] - 101s 2s/step - loss: 1001.4916 - mean_squared_error: 1001.4916 - val_loss: 13141.4785 - val_mean_squared_error: 13141.4785
# Epoch 19/20
# 50/50 [==============================] - 104s 2s/step - loss: 948.7060 - mean_squared_error: 948.7060 - val_loss: 11618.7695 - val_mean_squared_error: 11618.7695
# Epoch 20/20
# 50/50 [==============================] - 99s 2s/step - loss: 847.5330 - mean_squared_error: 847.5330 - val_loss: 10942.4990 - val_mean_squared_error: 10942.4990

# %%
history = hist
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
img_path='E:/cattle_data/img/ponoka/im_22053.png'
img = image.load_img(img_path, target_size=(224, 224), color_mode='rgb')
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x/255.
model_xcept.predict([x, x])
# Out:
# array([[1100.7622]], dtype=float32)

# %%
model_xcept.save(DATABASE_LOCATION+"/models/two_view_model")
# Out:
# INFO:tensorflow:Assets written to: E:/cattle_data/models/two_view_model\assets
# C:\Users\derek\anaconda3\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# C:\Users\derek\anaconda3\lib\site-packages\keras\saving\saved_model\layer_serialization.py:112: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   return generic_utils.serialize_keras_object(obj)

# %%
model_xcept = tf.keras.models.load_model(DATABASE_LOCATION+"/models/two_view_model")

# %%
history = hist
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Evaluate

# %%
from matplotlib.patches import Patch

def display_activation(model, image_frame):
    
    """
    Displays heatmaps of each layer overlaid onto the original image.
    :param model: Keras compiled model
    :param image_frame: The pandas frame from which to get the X and y data to feed the model.
    """
    
    img_path = image_frame.path
    if os.path.exists(img_path):
        img = image.load_img(img_path, target_size=(224, 224), color_mode=color)
        x = image.img_to_array(img)
        x = np.expand_dims(x, axis=0)
        x = x/255.

        activations = keract.get_activations(model, x, layer_names=None, nodes_to_evaluate=None, output_format='simple', nested=False, auto_compile=True)
        #keract.display_activations(activations, cmap=None, save=False, directory='.', data_format='channels_last', fig_size=(24, 24), reshape_1d_layers=False)
        keract.display_heatmaps(activations, x, save=False)
        #return heatmap, output
        
        
# Add padding to image
# Function taken from:
# https://note.nkmk.me/en/python-pillow-add-margin-expand-canvas/
def expand2square(pil_img, background_color):
    width, height = pil_img.size
    if width == height:
        return pil_img
    elif width > height:
        result = Image.new(pil_img.mode, (width, width), background_color)
        result.paste(pil_img, (0, (width - height) // 2))
        return result
    else:
        result = Image.new(pil_img.mode, (height, height), background_color)
        result.paste(pil_img, ((height - width) // 2, 0))
        return result
        
def load_img(img_path, target_size, color_mode):
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=None, color_mode=color_mode)
    img = expand2square(img, (0))
    img = tf.image.resize(
            img,
            size=target_size,
            preserve_aspect_ratio=True,
            antialias=False)
    x = tf.keras.preprocessing.image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = x/255.
    return x

        
def test_on_image(models, image_frame, model_labels = [], display_each=True, display_width = 3):
    
    """
    Run model on set of images in the given pandas frame. The image frame must include a ['path'] column to the image as well as a 
    ['weight'] column with the true values for the image. 
    
    :param model: Keras compiled model
    :param image_frame: The pandas frame from which to get the X and y data to feed through the model.
    :param display_each: (optional) If this is True, each image in the frame will be displayed inline along with its given truth
    and prediction.
    :param display_activation: (optional) If this is True, an activation map will be overlayed onto the image to show 
    "where the network is looking" for the given image. In this case, 'display_each' should also be set to True.
    :return: Prints the average error and accuracy of the given test set. Returns the accuracy score. 
    """
    p_times = 1
    p_m = 0
    
    # handle model_labels length mismatch
    if len(model_labels) == 0:
        for i in range(len(models)):
            model_labels.append('Model '+str(i))
            
    elif len(model_labels) != len(models):
        raise ValueError("Number of model labels does not match number of models")
    
    # display a loading bar
    if not display_each:
        pbar = tqdm(total=len(image_frame))
    
    else:
        display_width = min(display_width, len(image_frame))
        fig, ax = plt.subplots(max(len(image_frame)//display_width, 1), min(display_width, len(image_frame)), figsize=(7*display_width, 4*len(image_frame)//display_width))
        fig.tight_layout(h_pad=25)
        #plt.rcParams["figure.figsize"] = [12.2, 5.5]
        plt.rcParams["figure.autolayout"] = True
    
    error = np.zeros(len(models))
    
    non_existent = 0
    
    # test on all the models and all the images
    for i in range(len(image_frame)):
        
        img_side_path = image_frame.iloc[i].side_path
        img_end_path = image_frame.iloc[i].end_path
            
        if os.path.exists(img_side_path):
            
            x0 = load_img(img_side_path, target_size=(224,224), color_mode='rgb')
            x1 = load_img(img_end_path, target_size=(224,224), color_mode='rgb')
            pred = np.zeros((len(models), p_times))
            
            # get predictions from each model to be tested
            for j, model in enumerate(models):

                # set the color mode based on the number of color channels in the model
                if model.input_shape[0][3] == 1:
                    x_0 = x0[:, :, :, 1]
                    x_1 = x1[:, :, :, 1]
                else:
                    x_0 = x0
                    x_1 = x1
                
                for n in range(p_times):
                    pred[j, n] = model.predict([x_0, x_1])[0][0]
            
            # get the mean and error rate for predictions
            p_m = pred.std(axis=1)*2.576 # 99% confidance interval
            pred = pred.mean(axis=1)
            
            # display the results 
            if display_each:
                barwidth = 32
                font_size = 12
                gw, gh = 448, 224

                if type(ax) == np.ndarray:
                    if len(ax.shape) == 1:
                        a = ax[i]
                    else:
                        a = ax[i//3][i%3]
                else:
                    a = ax
                
                
                ax_ = a.twinx()
                ax_1 = ax_.twinx()
                
                im = a.imshow(np.concatenate((np.squeeze(x_0), np.squeeze(x_1)), axis=1), extent=[0, gw, 0, gh])
                horiz = np.array(range(barwidth, len(pred)*barwidth+barwidth, barwidth))
                acc = (1 - np.abs(np.full(len(pred), image_frame.iloc[i].weight) - np.array(pred))/np.full(len(pred), image_frame.iloc[i].weight))*100

                ax_.bar(x = horiz, tick_label = model_labels, width=barwidth, linewidth=2, edgecolor='black', height = acc, alpha=0.5)
                ax_1.bar(x = gw - np.flip(horiz, axis=0), tick_label = [label+'_' for label in np.flip(model_labels, axis=0)], width=barwidth, linewidth=2, color='orange', edgecolor='black', height = pred, alpha = 0.5)
                ax_1.bar(x = gw - barwidth*(len(pred)+1), width=barwidth*(len(pred)+1), linewidth=2, align='edge', color='red', edgecolor='white', height=image_frame.iloc[i].weight, alpha=0.2)
                
                # print accuracy values
                for k, val in enumerate(acc):
                    ax_.text(horiz[k] - 4, val/2 - 10, '{:.1f}%'.format(val), color = 'white', fontweight = 'bold', rotation = 'vertical', size=font_size)
                    
                # print weight values
                for k, (val, val1) in enumerate(zip(pred, p_m)):
                    ax_1.text(gw - horiz[k] - 4, val/2 - 250, '{:.1f}lb +-{:.1f}'.format(val, val1), color = 'white', fontweight = 'normal', rotation = 'vertical', size=font_size)
                    
                #ax_.set_aspect('equal', adjustable=None, anchor=None, share=False)
                legend_elements = [Patch(facecolor='red', edgecolor='black',
                             label='True Weight'),
                       Patch(facecolor='orange', edgecolor='black',
                             label='Predicted Weight'),
                       Patch(facecolor='C0', edgecolor='black',
                             label='Accuracy')]

                #ax_.set_ylabel('Accuracy')
                ax_.set_xticks(np.concatenate([horiz, gw-np.flip(horiz, axis=0)], axis=0), labels=np.concatenate([model_labels, model_labels], axis=0))
                ax_1.set_ylabel('Predicted Weight (lbs)') 
                ax_1.set_ylim(0, 1500)
                ax_.set_ylim(0, 120)
                ax_.set_yticks(range(0, 125, 25))
                a.set_yticks([])
                #a.set_ylabel('Percent Accuracy')
                a.tick_params(axis='x', labelrotation= 70)
                a.set_title('Actual Weight: {} lbs'.format(image_frame.iloc[i].weight))
                #print('Predicted: {} lbs, Actual: {} lbs'.format(pred, image_frame.iloc[i].weight))

            # accumulate the error over the set of inputs
            error += abs(image_frame.iloc[i].weight - pred) / image_frame.iloc[i].weight 
        else:
            non_existent += 1
        
        if not display_each:
            pbar.update(1)
    
    if display_each:
        fig.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(0., 0.92, 0.02, 0.102),
                          ncol=1, borderaxespad=0.)
        fig.suptitle('Model Comparison', fontsize=30, verticalalignment='top')
        #plt.xticks(rotation='vertical')
        plt.show()

    # calculate the error and accuracy as an average for the set
    #print('{} average Error Rate: {:.2f}%'.format(model_labels[j], error[j]*100 / (len(image_frame) - non_existent)))
    acc = (1-error / (len(image_frame) - non_existent))*100
    
    for i, label in enumerate(model_labels):
        print('{} average accuracy: {:.2f}%'.format(label, acc[i]))    
        
    return acc

# %%
n = np.array([[5,5.5, 6],[12,6,24]])

# %%
n.mean(axis=1)
# Out:
# array([ 5.5, 14. ])

# %%
X = eval_df.sample(n=6)

# %%
test_on_image([model_xcept], X, model_labels=['Xcept'], display_each=True);
# Out:
# Xcept average accuracy: 83.19%

# %%
result = test_on_image([model_xcept], eval_df, model_labels=['Xcept'], display_each=False)
# Out:
#   0%|          | 0/6202 [00:00<?, ?it/s]
# Xcept average accuracy: 84.41%
